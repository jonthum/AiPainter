# %%
#COLAB
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#STYLE TRANSFER - LI ET AL OPEN SOUCE


#VERSIONS
# %tensorflow_version 1.x
# !pip install q keras==2.0.9
# !pip install q scipy==1.0.0

#CLONE OPEN SOURCE CODE FROM GITHUB
# !git clone https://github.com/eridgd/WCT-TF
# %cd WCT-TF

#DOWNLOAD MODELS
# !sh models/download_vgg.sh
# !sh models/download_models.sh
# Out:
# TensorFlow 1.x selected.
# Collecting q
#   Downloading https://files.pythonhosted.org/packages/53/bc/51619d89e0bd855567e7652fa16d06f1ed36a85f108a7fe71f6629bf719d/q-2.6-py2.py3-none-any.whl
# Collecting keras==2.0.9
#   Downloading https://files.pythonhosted.org/packages/b6/5a/c7fe49396e9d14f89b05ea550f3d5f8c4cfb3af20e831a3d323fec2a0d5b/Keras-2.0.9-py2.py3-none-any.whl (299kB)
#      |████████████████████████████████| 307kB 11.8MB/s
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.0.9) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.0.9) (1.18.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.0.9) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.0.9) (3.13)
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.9 which is incompatible.
# Installing collected packages: q, keras
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.4.3 q-2.6
# Requirement already satisfied: q in /usr/local/lib/python3.6/dist-packages (2.6)
# Collecting scipy==1.0.0
#   Downloading https://files.pythonhosted.org/packages/d8/5e/caa01ba7be11600b6a9d39265440d7b3be3d69206da887c42bef049521f2/scipy-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (50.0MB)
#      |████████████████████████████████| 50.0MB 68kB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.0.0) (1.18.5)
# ERROR: umap-learn 0.4.6 has requirement scipy>=1.3.1, but you'll have scipy 1.0.0 which is incompatible.
# ERROR: seaborn 0.10.1 has requirement scipy>=1.0.1, but you'll have scipy 1.0.0 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.0.0 which is incompatible.
# ERROR: cvxpy 1.0.31 has requirement scipy>=1.1.0, but you'll have scipy 1.0.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# Successfully installed scipy-1.0.0
# Cloning into 'WCT-TF'...
# remote: Enumerating objects: 448, done.
# remote: Total 448 (delta 0), reused 0 (delta 0), pack-reused 448
# Receiving objects: 100% (448/448), 17.76 MiB | 13.39 MiB/s, done.
# Resolving deltas: 100% (287/287), done.
# /content/WCT-TF
# --2020-09-27 17:30:54--  https://www.dropbox.com/s/kh8izr3fkvhitfn/vgg_normalised.t7?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/kh8izr3fkvhitfn/vgg_normalised.t7 [following]
# --2020-09-27 17:30:54--  https://www.dropbox.com/s/dl/kh8izr3fkvhitfn/vgg_normalised.t7
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc67b6e3da993e88396b3592d8d5.dl.dropboxusercontent.com/cd/0/get/BAPk6fWMRiPOjMQ0zazbgpk93BrMU0qnA7_43bKX9BJlMHITYfkca6WD1zba1P52jtAf-iAI86y-bP_RHYJ6ix2_UG3yDo4gFtLroKjRr4eXSw/file?dl=1# [following]
# --2020-09-27 17:30:55--  https://uc67b6e3da993e88396b3592d8d5.dl.dropboxusercontent.com/cd/0/get/BAPk6fWMRiPOjMQ0zazbgpk93BrMU0qnA7_43bKX9BJlMHITYfkca6WD1zba1P52jtAf-iAI86y-bP_RHYJ6ix2_UG3yDo4gFtLroKjRr4eXSw/file?dl=1
# Resolving uc67b6e3da993e88396b3592d8d5.dl.dropboxusercontent.com (uc67b6e3da993e88396b3592d8d5.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uc67b6e3da993e88396b3592d8d5.dl.dropboxusercontent.com (uc67b6e3da993e88396b3592d8d5.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 160221189 (153M) [application/binary]
# Saving to: ‘vgg_normalised.t7’
#
# vgg_normalised.t7   100%[===================>] 152.80M  17.1MB/s    in 8.9s
#
# 2020-09-27 17:31:04 (17.3 MB/s) - ‘vgg_normalised.t7’ saved [160221189/160221189]
#
# --2020-09-27 17:31:04--  https://www.dropbox.com/s/ssg39coiih5hjzz/models.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/ssg39coiih5hjzz/models.zip [following]
# --2020-09-27 17:31:04--  https://www.dropbox.com/s/dl/ssg39coiih5hjzz/models.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf4ed9e77a5d249332a504ca4c4.dl.dropboxusercontent.com/cd/0/get/BAPf-DEuZbHYsh9XZP5bWyjUnasUCLS9AjJLiEZTHeUSF4YAuYQy3yKwnjUjywaCUziRLj0TurlSrc9dNk7lVNEY_33X7ErE1hN1rsOeQynIyg/file?dl=1# [following]
# --2020-09-27 17:31:05--  https://ucf4ed9e77a5d249332a504ca4c4.dl.dropboxusercontent.com/cd/0/get/BAPf-DEuZbHYsh9XZP5bWyjUnasUCLS9AjJLiEZTHeUSF4YAuYQy3yKwnjUjywaCUziRLj0TurlSrc9dNk7lVNEY_33X7ErE1hN1rsOeQynIyg/file?dl=1
# Resolving ucf4ed9e77a5d249332a504ca4c4.dl.dropboxusercontent.com (ucf4ed9e77a5d249332a504ca4c4.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to ucf4ed9e77a5d249332a504ca4c4.dl.dropboxusercontent.com (ucf4ed9e77a5d249332a504ca4c4.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 492852192 (470M) [application/binary]
# Saving to: ‘models.zip’
#
# models.zip          100%[===================>] 470.02M  21.3MB/s    in 21s
#
# 2020-09-27 17:31:27 (22.0 MB/s) - ‘models.zip’ saved [492852192/492852192]
#
# Archive:  models.zip
#    creating: relu3_1/
#   inflating: relu3_1/model.ckpt-15003.data-00000-of-00001
#   inflating: relu3_1/model.ckpt-15003.index
#   inflating: relu3_1/checkpoint
#   inflating: relu3_1/model.ckpt-15003.meta
#    creating: relu1_1/
#   inflating: relu1_1/model.ckpt-15002.index
#   inflating: relu1_1/model.ckpt-15002.meta
#   inflating: relu1_1/checkpoint
#   inflating: relu1_1/model.ckpt-15002.data-00000-of-00001
#    creating: relu2_1/
#   inflating: relu2_1/model.ckpt-15000.index
#   inflating: relu2_1/model.ckpt-15000.meta
#   inflating: relu2_1/model.ckpt-15000.data-00000-of-00001
#   inflating: relu2_1/checkpoint
#    creating: relu5_1/
#   inflating: relu5_1/model.ckpt-15004.index
#   inflating: relu5_1/model.ckpt-15004.meta
#   inflating: relu5_1/checkpoint
#   inflating: relu5_1/model.ckpt-15004.data-00000-of-00001
#    creating: relu4_1/
#   inflating: relu4_1/model.ckpt-15003.data-00000-of-00001
#   inflating: relu4_1/model.ckpt-15003.index
#   inflating: relu4_1/checkpoint
#   inflating: relu4_1/model.ckpt-15003.meta

# %%
#RUN STYLE TRANSFER
# !python stylize.py \
--checkpoints models/relu5_1 models/relu4_1 models/relu3_1 models/relu2_1 models/relu1_1 \
--relu-targets relu5_1 relu4_1 relu3_1 relu2_1 relu1_1 \
--alpha 0.8 \
--content-size 524 \
--style-size 1024 \
--content-path '/content/gdrive/My Drive/AiPainter/images/content/avril.jpg' \
--style-path '/content/gdrive/My Drive/AiPainter/images/style/la_muse.jpg' \
--out-path '/content/gdrive/My Drive/AiPainter/images/results' --adain
# Out:
# /content/gdrive/My Drive/AiPainter/images/content/avril.jpg
# Using TensorFlow backend.
# 2020-09-27 17:34:10.888353: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-09-27 17:34:10.893861: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000125000 Hz
# 2020-09-27 17:34:10.894104: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2978a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-27 17:34:10.894138: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-09-27 17:34:10.896129: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-09-27 17:34:11.015321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:11.016144: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2978bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-09-27 17:34:11.016182: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2020-09-27 17:34:11.016360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:11.017040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:04.0
# 2020-09-27 17:34:11.017363: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-27 17:34:11.018951: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-09-27 17:34:11.020516: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-09-27 17:34:11.020951: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-09-27 17:34:11.022507: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-09-27 17:34:11.023333: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-09-27 17:34:11.026407: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-09-27 17:34:11.026533: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:11.027220: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:11.027815: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-09-27 17:34:11.027879: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-27 17:34:11.029260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-27 17:34:11.029290: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-09-27 17:34:11.029302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-09-27 17:34:11.029422: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:11.030115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:11.030729: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-09-27 17:34:11.030774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 15024 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# WARNING:tensorflow:From /content/WCT-TF/model.py:15: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From /content/WCT-TF/wct.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /content/WCT-TF/model.py:43: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# Loading VGG up to layer relu5_1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:488: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3454: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg_input (InputLayer)       (None, None, None, 3)     0
# _________________________________________________________________
# preprocess (Conv2D)          (None, None, None, 3)     12
# _________________________________________________________________
# lambda_1 (Lambda)            (None, None, None, 3)     0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, None, None, 64)    1792
# _________________________________________________________________
# relu1_1 (Activation)         (None, None, None, 64)    0
# _________________________________________________________________
# lambda_2 (Lambda)            (None, None, None, 64)    0
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, None, None, 64)    36928
# _________________________________________________________________
# relu1_2 (Activation)         (None, None, None, 64)    0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, None, None, 64)    0
# _________________________________________________________________
# lambda_3 (Lambda)            (None, None, None, 64)    0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, None, None, 128)   73856
# _________________________________________________________________
# relu2_1 (Activation)         (None, None, None, 128)   0
# _________________________________________________________________
# lambda_4 (Lambda)            (None, None, None, 128)   0
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, None, None, 128)   147584
# _________________________________________________________________
# relu2_2 (Activation)         (None, None, None, 128)   0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, None, None, 128)   0
# _________________________________________________________________
# lambda_5 (Lambda)            (None, None, None, 128)   0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, None, None, 256)   295168
# _________________________________________________________________
# relu3_1 (Activation)         (None, None, None, 256)   0
# _________________________________________________________________
# lambda_6 (Lambda)            (None, None, None, 256)   0
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, None, None, 256)   590080
# _________________________________________________________________
# relu3_2 (Activation)         (None, None, None, 256)   0
# _________________________________________________________________
# lambda_7 (Lambda)            (None, None, None, 256)   0
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, None, None, 256)   590080
# _________________________________________________________________
# relu3_3 (Activation)         (None, None, None, 256)   0
# _________________________________________________________________
# lambda_8 (Lambda)            (None, None, None, 256)   0
# _________________________________________________________________
# conv3_4 (Conv2D)             (None, None, None, 256)   590080
# _________________________________________________________________
# relu3_4 (Activation)         (None, None, None, 256)   0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, None, None, 256)   0
# _________________________________________________________________
# lambda_9 (Lambda)            (None, None, None, 256)   0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, None, None, 512)   1180160
# _________________________________________________________________
# relu4_1 (Activation)         (None, None, None, 512)   0
# _________________________________________________________________
# lambda_10 (Lambda)           (None, None, None, 512)   0
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, None, None, 512)   2359808
# _________________________________________________________________
# relu4_2 (Activation)         (None, None, None, 512)   0
# _________________________________________________________________
# lambda_11 (Lambda)           (None, None, None, 512)   0
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, None, None, 512)   2359808
# _________________________________________________________________
# relu4_3 (Activation)         (None, None, None, 512)   0
# _________________________________________________________________
# lambda_12 (Lambda)           (None, None, None, 512)   0
# _________________________________________________________________
# conv4_4 (Conv2D)             (None, None, None, 512)   2359808
# _________________________________________________________________
# relu4_4 (Activation)         (None, None, None, 512)   0
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, None, None, 512)   0
# _________________________________________________________________
# lambda_13 (Lambda)           (None, None, None, 512)   0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, None, None, 512)   2359808
# _________________________________________________________________
# relu5_1 (Activation)         (None, None, None, 512)   0
# =================================================================
# Total params: 12,944,972
# Trainable params: 0
# Non-trainable params: 12,944,972
# _________________________________________________________________
# None
# Building encoder/decoder for relu target relu5_1
# WARNING:tensorflow:From /content/WCT-TF/ops.py:171: The name tf.svd is deprecated. Please use tf.linalg.svd instead.
#
# WARNING:tensorflow:From /content/WCT-TF/ops.py:188: The name tf.diag is deprecated. Please use tf.linalg.tensor_diag instead.
#
# WARNING:tensorflow:From /content/WCT-TF/ops.py:228: calling extract_image_patches (from tensorflow.python.ops.array_ops) with ksizes is deprecated and will be removed in a future version.
# Instructions for updating:
# ksizes is deprecated, use sizes instead
# WARNING:tensorflow:From /content/WCT-TF/ops.py:234: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From /content/WCT-TF/ops.py:262: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3626: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1818: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input_relu5_1 (Input (None, None, None, 512)   0
# _________________________________________________________________
# relu5_1_0 (Lambda)           (None, None, None, 512)   0
# _________________________________________________________________
# relu5_1_1 (UpSampling2D)     (None, None, None, 512)   0
# _________________________________________________________________
# relu5_1_2 (Lambda)           (None, None, None, 512)   0
# _________________________________________________________________
# relu5_1_3 (Lambda)           (None, None, None, 512)   0
# _________________________________________________________________
# relu5_1_4 (Lambda)           (None, None, None, 512)   0
# _________________________________________________________________
# relu5_1_5 (Lambda)           (None, None, None, 256)   0
# _________________________________________________________________
# relu5_1_6 (UpSampling2D)     (None, None, None, 256)   0
# _________________________________________________________________
# relu5_1_7 (Lambda)           (None, None, None, 256)   0
# _________________________________________________________________
# relu5_1_8 (Lambda)           (None, None, None, 256)   0
# _________________________________________________________________
# relu5_1_9 (Lambda)           (None, None, None, 256)   0
# _________________________________________________________________
# relu5_1_10 (Lambda)          (None, None, None, 128)   0
# _________________________________________________________________
# relu5_1_11 (UpSampling2D)    (None, None, None, 128)   0
# _________________________________________________________________
# relu5_1_12 (Lambda)          (None, None, None, 128)   0
# _________________________________________________________________
# relu5_1_13 (Lambda)          (None, None, None, 64)    0
# _________________________________________________________________
# relu5_1_14 (UpSampling2D)    (None, None, None, 64)    0
# _________________________________________________________________
# relu5_1_15 (Lambda)          (None, None, None, 64)    0
# _________________________________________________________________
# relu5_1_16 (Lambda)          (None, None, None, 3)     0
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________
# None
# Building encoder/decoder for relu target relu4_1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input_relu4_1 (Input (None, None, None, 512)   0
# _________________________________________________________________
# relu4_1_0 (Lambda)           (None, None, None, 256)   0
# _________________________________________________________________
# relu4_1_1 (UpSampling2D)     (None, None, None, 256)   0
# _________________________________________________________________
# relu4_1_2 (Lambda)           (None, None, None, 256)   0
# _________________________________________________________________
# relu4_1_3 (Lambda)           (None, None, None, 256)   0
# _________________________________________________________________
# relu4_1_4 (Lambda)           (None, None, None, 256)   0
# _________________________________________________________________
# relu4_1_5 (Lambda)           (None, None, None, 128)   0
# _________________________________________________________________
# relu4_1_6 (UpSampling2D)     (None, None, None, 128)   0
# _________________________________________________________________
# relu4_1_7 (Lambda)           (None, None, None, 128)   0
# _________________________________________________________________
# relu4_1_8 (Lambda)           (None, None, None, 64)    0
# _________________________________________________________________
# relu4_1_9 (UpSampling2D)     (None, None, None, 64)    0
# _________________________________________________________________
# relu4_1_10 (Lambda)          (None, None, None, 64)    0
# _________________________________________________________________
# relu4_1_11 (Lambda)          (None, None, None, 3)     0
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________
# None
# Building encoder/decoder for relu target relu3_1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input_relu3_1 (Input (None, None, None, 256)   0
# _________________________________________________________________
# relu3_1_0 (Lambda)           (None, None, None, 128)   0
# _________________________________________________________________
# relu3_1_1 (UpSampling2D)     (None, None, None, 128)   0
# _________________________________________________________________
# relu3_1_2 (Lambda)           (None, None, None, 128)   0
# _________________________________________________________________
# relu3_1_3 (Lambda)           (None, None, None, 64)    0
# _________________________________________________________________
# relu3_1_4 (UpSampling2D)     (None, None, None, 64)    0
# _________________________________________________________________
# relu3_1_5 (Lambda)           (None, None, None, 64)    0
# _________________________________________________________________
# relu3_1_6 (Lambda)           (None, None, None, 3)     0
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________
# None
# Building encoder/decoder for relu target relu2_1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input_relu2_1 (Input (None, None, None, 128)   0
# _________________________________________________________________
# relu2_1_0 (Lambda)           (None, None, None, 64)    0
# _________________________________________________________________
# relu2_1_1 (UpSampling2D)     (None, None, None, 64)    0
# _________________________________________________________________
# relu2_1_2 (Lambda)           (None, None, None, 64)    0
# _________________________________________________________________
# relu2_1_3 (Lambda)           (None, None, None, 3)     0
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________
# None
# Building encoder/decoder for relu target relu1_1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input_relu1_1 (Input (None, None, None, 64)    0
# _________________________________________________________________
# relu1_1_0 (Lambda)           (None, None, None, 64)    0
# _________________________________________________________________
# relu1_1_1 (Lambda)           (None, None, None, 3)     0
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From /content/WCT-TF/wct.py:40: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/WCT-TF/wct.py:42: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-09-27 17:34:14.395812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:14.396474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:04.0
# 2020-09-27 17:34:14.396545: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-27 17:34:14.396569: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-09-27 17:34:14.396611: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-09-27 17:34:14.396631: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-09-27 17:34:14.396653: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-09-27 17:34:14.396673: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-09-27 17:34:14.396694: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-09-27 17:34:14.396780: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:14.397543: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:14.398163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-09-27 17:34:14.398211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-27 17:34:14.398228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-09-27 17:34:14.398239: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-09-27 17:34:14.398337: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:14.398994: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-27 17:34:14.399602: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15024 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# WARNING:tensorflow:From /content/WCT-TF/wct.py:44: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/WCT-TF/wct.py:49: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/WCT-TF/wct.py:51: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Restoring vars for relu5_1 from checkpoint models/relu5_1/model.ckpt-15004
# Restoring vars for relu4_1 from checkpoint models/relu4_1/model.ckpt-15003
# Restoring vars for relu3_1 from checkpoint models/relu3_1/model.ckpt-15003
# Restoring vars for relu2_1 from checkpoint models/relu2_1/model.ckpt-15000
# Restoring vars for relu1_1 from checkpoint models/relu1_1/model.ckpt-15002
# Traceback (most recent call last):
#   File "stylize.py", line 126, in <module>
#     main()
#   File "stylize.py", line 74, in main
#     content_img = get_img(content_fullpath)
#   File "/content/WCT-TF/utils.py", line 24, in get_img
#     img = scipy.misc.imread(src, mode='RGB')
#   File "/usr/local/lib/python3.6/dist-packages/numpy/lib/utils.py", line 101, in newfunc
#     return func(*args, **kwds)
#   File "/usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py", line 164, in imread
#     im = Image.open(name)
#   File "/usr/local/lib/python3.6/dist-packages/PIL/Image.py", line 2809, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: 'CONTENT'
