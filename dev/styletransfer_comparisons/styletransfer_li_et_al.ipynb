# %%
#COLAB
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#STYLE TRANSFER - LI ET AL OPEN SOUCE


#VERSIONS
# %tensorflow_version 1.x
# !pip install q keras==2.0.9
# !pip install q scipy==1.0.0

#CLONE OPEN SOURCE CODE FROM GITHUB
# !git clone https://github.com/eridgd/WCT-TF

#CLONE DIRECTORY STRUCTURE
# !git clone https://github.com/jonthum/AiPainter

# %cd WCT-TF

#DOWNLOAD MODELS
# !sh models/download_vgg.sh
# !sh models/download_models.sh
# Out:
# TensorFlow 1.x selected.
# ...
#      |████████████████████████████████| 307kB 3.7MB/s
# ...
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.9 which is incompatible.
# ...
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...
#      |████████████████████████████████| 50.0MB 59kB/s
# ...
# ERROR: umap-learn 0.4.6 has requirement scipy>=1.3.1, but you'll have scipy 1.0.0 which is incompatible.
# ERROR: seaborn 0.10.1 has requirement scipy>=1.0.1, but you'll have scipy 1.0.0 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.0.0 which is incompatible.
# ERROR: cvxpy 1.0.31 has requirement scipy>=1.1.0, but you'll have scipy 1.0.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
# ...

# %%
#RUN STYLE TRANSFER
# !python stylize.py \
--checkpoints models/relu5_1 models/relu4_1 models/relu3_1 models/relu2_1 models/relu1_1 \
--relu-targets relu5_1 relu4_1 relu3_1 relu2_1 relu1_1 \
--alpha 0.8 \
--content-size 524 \
--style-size 1024 \
--content-path '/content/AiPainter/images/content/avril.jpg' \
--style-path '/content/AiPainter/images/style/la_muse.jpg' \
--out-path '/content/AiPainter/images/results' --adain
# Out:
# Using TensorFlow backend.
# 2020-09-29 08:21:02.646494: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-09-29 08:21:02.646802: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2866a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-29 08:21:02.646843: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-09-29 08:21:02.649777: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-09-29 08:21:02.836521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
